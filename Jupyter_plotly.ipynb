# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import json

# Zbiór danych

df = pd.read_csv("three_class_dataframe_performance.csv")

# Wizualizacje danych



ax = px.histogram(df, x ='BMI')

ax


px.bar(df, x = '')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
df_2 = df.groupby('class')['body fat_%'].mean().reset_index

# %%
df_2 = df_2.rename()
# Out:
# <bound method Series.reset_index of class
# A    20.538979
# B    22.441232
# C    27.746715
# Name: body fat_%, dtype: float64>

# %%
df_2 = pd.DataFrame({'count' : df.groupby('class')['body fat_%'].mean()}).reset_index() 

df_2
# Out:
#   class      count
# 0     A  20.538979
# 1     B  22.441232
# 2     C  27.746715

# %%
px.bar(df_2, x = 'class', y = 'count')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Paweł\PycharmProjects\Flask_app\venv\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...
